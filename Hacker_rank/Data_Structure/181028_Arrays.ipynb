# %% [markdown]
# ![/img/Array.png](attachment:image.png)

# %%
def reverseArray(a) : 
    result = []
    n = len(a)
    for i in range(n) : 
        n -= 1
        result.insert(i, a[n])
    return result

# %%
arr = list(map(int, input().rstrip().split()))
# Out:
# 1 4 3 2

# %%
reverseArray(arr)
# Out:
# [2, 3, 4, 1]
